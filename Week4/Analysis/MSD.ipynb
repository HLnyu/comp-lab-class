# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mdtraj as md

# %%
df1= pd.read_csv('./SOD_msd.xvg',skiprows=20,sep='\s+',header=None)
df1.columns = [ "Time (ps)","S" ]
df1
# Out:
#      Time (ps)          S
# 0            0   0.000000
# 1           10   0.291248
# 2           20   0.554751
# 3           30   0.808535
# 4           40   1.053310
# ..         ...        ...
# 96         960  18.297900
# 97         970  19.079400
# 98         980  19.005800
# 99         990  19.022800
# 100       1000  19.039000
#
# [101 rows x 2 columns]

# %%
df2= pd.read_csv('./CLA_msd.xvg',skiprows=20,sep='\s+',header=None)
df2.columns = [ "Time (ps)","CLA" ]
df2
# Out:
#      Time (ps)        CLA
# 0            0   0.000000
# 1           10   0.327675
# 2           20   0.628792
# 3           30   0.957634
# 4           40   1.265590
# ..         ...        ...
# 96         960  39.324000
# 97         970  40.865700
# 98         980  42.996100
# 99         990  43.093600
# 100       1000  42.455300
#
# [101 rows x 2 columns]

# %%
df3= pd.read_csv('./Water_msd.xvg',skiprows=20,sep='\s+',header=None)
df3.columns = [ "Time (ps)","water" ]
df3
# Out:
#      Time (ps)     water
# 0            0   0.00000
# 1           10   0.51456
# 2           20   1.00554
# 3           30   1.48809
# 4           40   1.94768
# ..         ...       ...
# 96         960  39.13900
# 97         970  40.08870
# 98         980  41.03700
# 99         990  41.54040
# 100       1000  41.78860
#
# [101 rows x 2 columns]

# %%
plt.plot(df1["Time (ps)"],df1["S"], 'g',linewidth=3,linestyle='dashed',label='S')
plt.plot(df2["Time (ps)"],df2["CLA"], 'b',linewidth=3,linestyle='dashed',label='CLA')
plt.plot(df3["Time (ps)"],df3["water"], 'pink',linewidth=3,linestyle='dashed',label='water')
plt.title('MSD VS Time(ps)')
plt.xlabel(" Time(ps) ")
plt.ylabel(" MSD ")
plt.legend()
plt.show()
